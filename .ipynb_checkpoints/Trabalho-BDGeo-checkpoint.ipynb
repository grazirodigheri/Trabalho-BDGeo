# %% [markdown]
# # **ÁREA DE SOJA CULTIVADA FRENTE A ANOMALIAS CLIMÁTICAS**
#
#
# - **Nome**: Grazieli Rodigheri
#
# - **Apresentação inicial**: 30 de outubro de 2020
#
# <hr style="border: 1px solid #0984e3;">

# %%
# !pip install stac.py
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting stac.py
#   Downloading stac.py-0.9.0.post11.tar.gz (49 kB)
#      |████████████████████████████████| 49 kB 1.9 MB/s eta 0:00:01
# Requirement already satisfied: Click>=7.0 in /usr/lib/python3.9/site-packages (from stac.py) (8.0.1)
# Requirement already satisfied: requests>=2.20 in /usr/lib/python3.9/site-packages (from stac.py) (2.25.1)
# Requirement already satisfied: jsonschema>=3.2 in /home/grodigheri/.local/lib/python3.9/site-packages (from stac.py) (3.2.0)
# Requirement already satisfied: Jinja2>=2.11.1 in /usr/lib/python3.9/site-packages (from stac.py) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3.9/site-packages (from Jinja2>=2.11.1->stac.py) (2.0.1)
# Requirement already satisfied: setuptools in /usr/lib/python3.9/site-packages (from jsonschema>=3.2->stac.py) (56.2.0)
# Requirement already satisfied: six>=1.11.0 in /usr/lib/python3.9/site-packages (from jsonschema>=3.2->stac.py) (1.16.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/lib/python3.9/site-packages (from jsonschema>=3.2->stac.py) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /home/grodigheri/.local/lib/python3.9/site-packages (from jsonschema>=3.2->stac.py) (21.2.0)
# Requirement already satisfied: chardet>=3.0.2 in /usr/lib/python3.9/site-packages (from requests>=2.20->stac.py) (4.0.0)
# Requirement already satisfied: idna>=2.5 in /usr/lib/python3.9/site-packages (from requests>=2.20->stac.py) (3.1)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/lib/python3.9/site-packages (from requests>=2.20->stac.py) (1.26.5)
# Collecting Shapely<2,>=1.7
#   Downloading Shapely-1.7.1-1-cp39-cp39-manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 2.2 MB/s eta 0:00:01
# Using legacy 'setup.py install' for stac.py, since package 'wheel' is not installed.
# Installing collected packages: Shapely, stac.py
#     Running setup.py install for stac.py ... done
# Successfully installed Shapely-1.7.1 stac.py-0.9.0.post11

# %%
import stac

# %%
service = stac.STAC('https://brazildatacube.dpi.inpe.br/stac/', access_token='ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N')

# %%
service
# Out:
# stac("https://brazildatacube.dpi.inpe.br/stac/")

# %%
collection = service.collection('MOD13Q1-6')
collection
# Out:
# {'id': 'MOD13Q1-6',
#  'stac_version': '0.9.0',
#  'stac_extensions': ['commons', 'datacube', 'version'],
#  'title': 'TERRA - MODIS - MOD13Q1 - C6',
#  'version': 6,
#  'deprecated': False,
#  'description': 'The Terra Moderate Resolution Imaging Spectroradiometer (MODIS) Vegetation Indices (MOD13Q1) Version 6 data are generated every 16 days at 250 meter (m) spatial resolution as a Level 3 product. The MOD13Q1 product provides two primary vegetation layers. The first is the Normalized Difference Vegetation Index (NDVI) which is referred to as the continuity index to the existing National Oceanic and Atmospheric Administration-Advanced Very High Resolution Radiometer (NOAA-AVHRR) derived NDVI. The second vegetation layer is the Enhanced Vegetation Index (EVI), which has improved sensitivity over high biomass regions. The algorithm chooses the best available pixel value from all the acquisitions from the 16 day period. The criteria used is low clouds, low view angle, and the highest NDVI/EVI value.',
#  'license': '',
#  'properties': {'eo:gsd': 250.0,
#   'eo:bands': [{'name': 'view_zenith_angle',
#     'common_name': '',
#     'description': 'View zenith angle of VI Pixel',
#     'min': 0.0,
#     'max': 18000.0,
#     'nodata': -10000.0,
#     'scale': 0.01,
#     'center_wavelength': None,
#     'full_width_half_max': None,
#     'data_type': 'int16'},
#    {'name': 'sun_zenith_angle',
#     'common_name': '',
#     'description': 'Sun zenith angle of VI pixel',
#     'min': 0.0,
#     'max': 18000.0,
#     'nodata': -10000.0,
#     'scale': 0.01,
#     'center_wavelength': None,
#     'full_width_half_max': None,
#     'data_type': 'int16'},
#    {'name': 'pixel_reliability',
#     'common_name': 'quality',
#     'description': 'Quality reliability of VI pixel',
#     'min': 0.0,
#     'max': 3.0,
#     'nodata': -1.0,
#     'scale': 1.0,
#     'center_wavelength': None,
#     'full_width_half_max': None,
#     'data_type': 'int16'},
#    {'name': 'relative_azimuth_angle',
#     'common_name': '',
#     'description': 'Relative azimuth angle of VI pixel',
#     'min': -18000.0,
#     'max': 18000.0,
#     'nodata': -10000.0,
#     'scale': 0.01,
#     'center_wavelength': None,
#     'full_width_half_max': None,
#     'data_type': 'int16'},
#    {'name': 'blue_reflectance',
#     'common_name': 'blue',
#     'description': 'Surface Reflectance Band 3',
#     'min': 0.0,
#     'max': 10000.0,
#     'nodata': -1000.0,
#     'scale': 0.0001,
#     'center_wavelength': 0.469,
#     'full_width_half_max': 0.01,
#     'data_type': 'int16'},
#    {'name': 'red_reflectance',
#     'common_name': 'red',
#     'description': 'Surface Reflectance Band 1',
#     'min': 0.0,
#     'max': 10000.0,
#     'nodata': -1000.0,
#     'scale': 0.0001,
#     'center_wavelength': 0.645,
#     'full_width_half_max': 0.025,
#     'data_type': 'int16'},
#    {'name': 'NIR_reflectance',
#     'common_name': 'nir',
#     'description': 'Surface Reflectance Band 2',
#     'min': 0.0,
#     'max': 10000.0,
#     'nodata': -1000.0,
#     'scale': 0.0001,
#     'center_wavelength': 0.8585,
#     'full_width_half_max': 0.175,
#     'data_type': 'int16'},
#    {'name': 'MIR_reflectance',
#     'common_name': 'swir22',
#     'description': 'Surface Reflectance Band 7',
#     'min': 0.0,
#     'max': 10000.0,
#     'nodata': -1000.0,
#     'scale': 0.0001,
#     'center_wavelength': 0.213,
#     'full_width_half_max': 0.0025,
#     'data_type': 'int16'},
#    {'name': 'NDVI',
#     'common_name': 'NDVI',
#     'description': '16 day NDVI',
#     'min': -2000.0,
#     'max': 10000.0,
#     'nodata': -3000.0,
#     'scale': 0.0001,
#     'center_wavelength': None,
#     'full_width_half_max': None,
#     'data_type': 'int16'},
#    {'name': 'EVI',
#     'common_name': 'EVI',
#     'description': '16 day EVI',
#     'min': -2000.0,
#     'max': 10000.0,
#     'nodata': -3000.0,
#     'scale': 0.0001,
#     'center_wavelength': None,
#     'full_width_half_max': None,
#     'data_type': 'int16'},
#    {'name': 'VI_Quality',
#     'common_name': 'quality',
#     'description': 'VI quality indicators',
#     'min': 0.0,
#     'max': 65534.0,
#     'nodata': 65535.0,
#     'scale': 1.0,
#     'center_wavelength': None,
#     'full_width_half_max': None,
#     'data_type': 'uint16'},
#    {'name': 'composite_day_of_the_year',
#     'common_name': 'quality',
#     'description': 'Day of year VI pixel',
#     'min': 1.0,
#     'max': 366.0,
#     'nodata': -1.0,
#     'scale': 1.0,
#     'center_wavelength': None,
#     'full_width_half_max': None,
#     'data_type': 'int16'}],
#   'instruments': ['MODIS'],
#   'platform': 'TERRA'},
#  'extent': {'spatial': {'bbox': [[-81.234129, -40.0, -30.0, 10.0]]},
#   'temporal': {'interval': [['2000-02-18T00:00:00', '2021-03-22T00:00:00']]}},
#  'bdc:bands_quicklook': ['red_reflectance',
#   'NIR_reflectance',
#   'blue_reflectance'],
#  'bdc:metadata': {'sources': [],
#   'datacite': {'id': 'MOD13Q1',
#    'dates': [{'date': '2020'}],
#    'sizes': [],
#    'state': 'unfindable',
#    'types': {'ris': 'DATA',
#     'bibtex': 'misc',
#     'citeproc': 'dataset',
#     'schemaOrg': 'Dataset',
#     'resourceType': 'Dataset',
#     'resourceTypeGeneral': 'Dataset'},
#    'agency': 'USGS',
#    'titles': {'lang': 'en', 'title': 'MODIS MOD13Q1'},
#    'formats': [],
#    'version': '4.',
#    'creators': [{'@type': 'Organization',
#      'familyName': 'National Aeronautics and Space Administration (NASA)'}],
#    'language': 'en',
#    'subjects': [{'lang': 'en', 'subject': 'MODIS'},
#     {'lang': 'en', 'subject': 'Surface Reflectance'}],
#    'rightsList': [{'rights': 'Terms and Conditions for the use and distribution of NASA Terra and Aqua MODIS, Suomi NPP, and other Collections Data',
#      'rightsUri': 'https://modaps.modaps.eosdis.nasa.gov/services/faq/LAADS_Data-Use_Citation_Policies.pdf'}],
#    'contributors': [{'name': 'National Institute for Space Research (INPE)',
#      'nameType': 'Organizational',
#      'contributorType': 'HostingInstitution'},
#     {'name': 'Brazil Data Cube Team', 'contributorType': 'ResearchGroup'}],
#    'descriptions': [{'lang': 'en',
#      'description': 'The Terra Moderate Resolution Imaging Spectroradiometer (MODIS) Vegetation Indices (MOD13Q1) Version 6 data are generated every 16 days at 250 meter (m) spatial resolution as a Level 3 product. The MOD13Q1 product provides two primary vegetation layers. The first is the Normalized Difference Vegetation Index (NDVI) which is referred to as the continuity index to the existing National Oceanic and Atmospheric Administration-Advanced Very High Resolution Radiometer (NOAA-AVHRR) derived NDVI. The second vegetation layer is the Enhanced Vegetation Index (EVI), which has improved sensitivity over high biomass regions. The algorithm chooses the best available pixel value from all the acquisitions from the 16 day period. The criteria used is low clouds, low view angle, and the highest NDVI/EVI value. Along with the vegetation layers and the two quality layers, the HDF file will have MODIS reflectance bands 1 (red), 2 (near-infrared), 3 (blue), and 7 (mid-infrared), as well as four observation layers. For more information on MOD13Q1, please, see https://lpdaac.usgs.gov/products/mod13q1v006/. This copy of the dataset was collected and made available by the Brazil Data Cube project, a component of the Environmental Monitoring of Brazilian Biomes project, funded by the Amazon Fund through the financial collaboration of the Brazilian Development Bank (BNDES) and the Foundation for Science, Technology and Space Applications (FUNCATE) no. 17.2.0536.1.',
#      'descriptionType': 'Abstract'}],
#    'geoLocations': [],
#    'schemaVersion': 'http://datacite.org/schema/kernel-4',
#    'fundingReferences': [{'funderName': 'Brazilian Development Bank (BNDES)'}],
#    'relatedIdentifiers': [{'title': "MODIS Vegetation Index User's Guide (MOD13 Series)",
#      'relationType': 'IsDescribedBy',
#      'relatedIdentifier': 'https://lpdaac.usgs.gov/documents/103/MOD13_User_Guide_V6.pdf',
#      'resourceTypeGeneral': 'Text',
#      'relatedIdentifierType': 'URL',
#      'relatedMetadataScheme': 'application/pdf'},
#     {'title': 'Using Remote Sensing Images and Cloud Services on AWS to Improve Land Use and Cover Monitoring',
#      'relationType': 'IsCitedBy',
#      'relatedIdentifier': '10.1109/LAGIRS48042.2020.9165649',
#      'relatedIdentifierType': 'DOI'},
#     {'title': 'Earth Observation Data Cubes for Brazil: Requirements, Methodology and Products ',
#      'relationType': 'IsCitedBy',
#      'relatedIdentifier': '10.3390/rs12244033',
#      'relatedIdentifierType': 'DOI'}]},
#   'processors': [{'uri': None, 'name': None, 'version': None}]},
#  'bdc:grs': 'STG',
#  'bdc:tiles': ['011008',
#   '012012',
#   '014011',
#   '010009',
#   '011010',
#   '013011',
#   '012009',
#   '011011',
#   '013012',
#   '013008',
#   '012010',
#   '012011',
#   '012008',
#   '014009',
#   '011009',
#   '014010',
#   '013010',
#   '013009'],
#  'bdc:composite_function': None,
#  'bdc:type': 'cube',
#  'cube:dimensions': {'x': {'type': 'spatial',
#    'axis': 'x',
#    'extent': [-81.234129, -30.0],
#    'reference_system': '+proj=sinu +lon_0=0 +x_0=0 +y_0=0 +a=6371007.181 +b=6371007.181 +units=m +no_defs '},
#   'y': {'type': 'spatial',
#    'axis': 'y',
#    'extent': [-40.0, 10.0],
#    'reference_system': '+proj=sinu +lon_0=0 +x_0=0 +y_0=0 +a=6371007.181 +b=6371007.181 +units=m +no_defs '},
#   'temporal': {'type': 'temporal',
#    'extent': ['2000-02-18T00:00:00', '2021-03-22T00:00:00'],
#    'values': ['2000-02-18',
#     '2000-03-05',
#     '2000-03-21',
#     '2000-04-06',
#     '2000-04-22',
#     '2000-05-08',
#     '2000-05-24',
#     '2000-06-09',
#     '2000-06-25',
#     '2000-07-11',
#     '2000-07-27',
#     '2000-08-12',
#     '2000-08-28',
#     '2000-09-13',
#     '2000-09-29',
#     '2000-10-15',
#     '2000-10-31',
#     '2000-11-16',
#     '2000-12-02',
#     '2000-12-18',
#     '2001-01-01',
#     '2001-01-17',
#     '2001-02-02',
#     '2001-02-18',
#     '2001-03-06',
#     '2001-03-22',
#     '2001-04-07',
#     '2001-04-23',
#     '2001-05-09',
#     '2001-05-25',
#     '2001-06-10',
#     '2001-06-26',
#     '2001-07-12',
#     '2001-07-28',
#     '2001-08-13',
#     '2001-08-29',
#     '2001-09-14',
#     '2001-09-30',
#     '2001-10-16',
#     '2001-11-01',
#     '2001-11-17',
#     '2001-12-03',
#     '2001-12-19',
#     '2002-01-01',
#     '2002-01-17',
#     '2002-02-02',
#     '2002-02-18',
#     '2002-03-06',
#     '2002-03-22',
#     '2002-04-07',
#     '2002-04-23',
#     '2002-05-09',
#     '2002-05-25',
#     '2002-06-10',
#     '2002-06-26',
#     '2002-07-12',
#     '2002-07-28',
#     '2002-08-13',
#     '2002-08-29',
#     '2002-09-14',
#     '2002-09-30',
#     '2002-10-16',
#     '2002-11-01',
#     '2002-11-17',
#     '2002-12-03',
#     '2002-12-19',
#     '2003-01-01',
#     '2003-01-17',
#     '2003-02-02',
#     '2003-02-18',
#     '2003-03-06',
#     '2003-03-22',
#     '2003-04-07',
#     '2003-04-23',
#     '2003-05-09',
#     '2003-05-25',
#     '2003-06-10',
#     '2003-06-26',
#     '2003-07-12',
#     '2003-07-28',
#     '2003-08-13',
#     '2003-08-29',
#     '2003-09-14',
#     '2003-09-30',
#     '2003-10-16',
#     '2003-11-01',
#     '2003-11-17',
#     '2003-12-03',
#     '2003-12-19',
#     '2004-01-01',
#     '2004-01-17',
#     '2004-02-02',
#     '2004-02-18',
#     '2004-03-05',
#     '2004-03-21',
#     '2004-04-06',
#     '2004-04-22',
#     '2004-05-08',
#     '2004-05-24',
#     '2004-06-09',
#     '2004-06-25',
#     '2004-07-11',
#     '2004-07-27',
#     '2004-08-12',
#     '2004-08-28',
#     '2004-09-13',
#     '2004-09-29',
#     '2004-10-15',
#     '2004-10-31',
#     '2004-11-16',
#     '2004-12-02',
#     '2004-12-18',
#     '2005-01-01',
#     '2005-01-17',
#     '2005-02-02',
#     '2005-02-18',
#     '2005-03-06',
#     '2005-03-22',
#     '2005-04-07',
#     '2005-04-23',
#     '2005-05-09',
#     '2005-05-25',
#     '2005-06-10',
#     '2005-06-26',
#     '2005-07-12',
#     '2005-07-28',
#     '2005-08-13',
#     '2005-08-29',
#     '2005-09-14',
#     '2005-09-30',
#     '2005-10-16',
#     '2005-11-01',
#     '2005-11-17',
#     '2005-12-03',
#     '2005-12-19',
#     '2006-01-01',
#     '2006-01-17',
#     '2006-02-02',
#     '2006-02-18',
#     '2006-03-06',
#     '2006-03-22',
#     '2006-04-07',
#     '2006-04-23',
#     '2006-05-09',
#     '2006-05-25',
#     '2006-06-10',
#     '2006-06-26',
#     '2006-07-12',
#     '2006-07-28',
#     '2006-08-13',
#     '2006-08-29',
#     '2006-09-14',
#     '2006-09-30',
#     '2006-10-16',
#     '2006-11-01',
#     '2006-11-17',
#     '2006-12-03',
#     '2006-12-19',
#     '2007-01-01',
#     '2007-01-17',
#     '2007-02-02',
#     '2007-02-18',
#     '2007-03-06',
#     '2007-03-22',
#     '2007-04-07',
#     '2007-04-23',
#     '2007-05-09',
#     '2007-05-25',
#     '2007-06-10',
#     '2007-06-26',
#     '2007-07-12',
#     '2007-07-28',
#     '2007-08-13',
#     '2007-08-29',
#     '2007-09-14',
#     '2007-09-30',
#     '2007-10-16',
#     '2007-11-01',
#     '2007-11-17',
#     '2007-12-03',
#     '2007-12-19',
#     '2008-01-01',
#     '2008-01-17',
#     '2008-02-02',
#     '2008-02-18',
#     '2008-03-05',
#     '2008-03-21',
#     '2008-04-06',
#     '2008-04-22',
#     '2008-05-08',
#     '2008-05-24',
#     '2008-06-09',
#     '2008-06-25',
#     '2008-07-11',
#     '2008-07-27',
#     '2008-08-12',
#     '2008-08-28',
#     '2008-09-13',
#     '2008-09-29',
#     '2008-10-15',
#     '2008-10-31',
#     '2008-11-16',
#     '2008-12-02',
#     '2008-12-18',
#     '2009-01-01',
#     '2009-01-17',
#     '2009-02-02',
#     '2009-02-18',
#     '2009-03-06',
#     '2009-03-22',
#     '2009-04-07',
#     '2009-04-23',
#     '2009-05-09',
#     '2009-05-25',
#     '2009-06-10',
#     '2009-06-26',
#     '2009-07-12',
#     '2009-07-28',
#     '2009-08-13',
#     '2009-08-29',
#     '2009-09-14',
#     '2009-09-30',
#     '2009-10-16',
#     '2009-11-01',
#     '2009-11-17',
#     '2009-12-03',
#     '2009-12-19',
#     '2010-01-01',
#     '2010-01-17',
#     '2010-02-02',
#     '2010-02-18',
#     '2010-03-06',
#     '2010-03-22',
#     '2010-04-07',
#     '2010-04-23',
#     '2010-05-09',
#     '2010-05-25',
#     '2010-06-10',
#     '2010-06-26',
#     '2010-07-12',
#     '2010-07-28',
#     '2010-08-13',
#     '2010-08-29',
#     '2010-09-14',
#     '2010-09-30',
#     '2010-10-16',
#     '2010-11-01',
#     '2010-11-17',
#     '2010-12-03',
#     '2010-12-19',
#     '2011-01-01',
#     '2011-01-17',
#     '2011-02-02',
#     '2011-02-18',
#     '2011-03-06',
#     '2011-03-22',
#     '2011-04-07',
#     '2011-04-23',
#     '2011-05-09',
#     '2011-05-25',
#     '2011-06-10',
#     '2011-06-26',
#     '2011-07-12',
#     '2011-07-28',
#     '2011-08-13',
#     '2011-08-29',
#     '2011-09-14',
#     '2011-09-30',
#     '2011-10-16',
#     '2011-11-01',
#     '2011-11-17',
#     '2011-12-03',
#     '2011-12-19',
#     '2012-01-01',
#     '2012-01-17',
#     '2012-02-02',
#     '2012-02-18',
#     '2012-03-05',
#     '2012-03-21',
#     '2012-04-06',
#     '2012-04-22',
#     '2012-05-08',
#     '2012-05-24',
#     '2012-06-09',
#     '2012-06-25',
#     '2012-07-11',
#     '2012-07-27',
#     '2012-08-12',
#     '2012-08-28',
#     '2012-09-13',
#     '2012-09-29',
#     '2012-10-15',
#     '2012-10-31',
#     '2012-11-16',
#     '2012-12-02',
#     '2012-12-18',
#     '2013-01-01',
#     '2013-01-17',
#     '2013-02-02',
#     '2013-02-18',
#     '2013-03-06',
#     '2013-03-22',
#     '2013-04-07',
#     '2013-04-23',
#     '2013-05-09',
#     '2013-05-25',
#     '2013-06-10',
#     '2013-06-26',
#     '2013-07-12',
#     '2013-07-28',
#     '2013-08-13',
#     '2013-08-29',
#     '2013-09-14',
#     '2013-09-30',
#     '2013-10-16',
#     '2013-11-01',
#     '2013-11-17',
#     '2013-12-03',
#     '2013-12-19',
#     '2014-01-01',
#     '2014-01-17',
#     '2014-02-02',
#     '2014-02-18',
#     '2014-03-06',
#     '2014-03-22',
#     '2014-04-07',
#     '2014-04-23',
#     '2014-05-09',
#     '2014-05-25',
#     '2014-06-10',
#     '2014-06-26',
#     '2014-07-12',
#     '2014-07-28',
#     '2014-08-13',
#     '2014-08-29',
#     '2014-09-14',
#     '2014-09-30',
#     '2014-10-16',
#     '2014-11-01',
#     '2014-11-17',
#     '2014-12-03',
#     '2014-12-19',
#     '2015-01-01',
#     '2015-01-17',
#     '2015-02-02',
#     '2015-02-18',
#     '2015-03-06',
#     '2015-03-22',
#     '2015-04-07',
#     '2015-04-23',
#     '2015-05-09',
#     '2015-05-25',
#     '2015-06-10',
#     '2015-06-26',
#     '2015-07-12',
#     '2015-07-28',
#     '2015-08-13',
#     '2015-08-29',
#     '2015-09-14',
#     '2015-09-30',
#     '2015-10-16',
#     '2015-11-01',
#     '2015-11-17',
#     '2015-12-03',
#     '2015-12-19',
#     '2016-01-01',
#     '2016-01-17',
#     '2016-02-02',
#     '2016-02-18',
#     '2016-03-05',
#     '2016-03-21',
#     '2016-04-06',
#     '2016-04-22',
#     '2016-05-08',
#     '2016-05-24',
#     '2016-06-09',
#     '2016-06-25',
#     '2016-07-11',
#     '2016-07-27',
#     '2016-08-12',
#     '2016-08-28',
#     '2016-09-13',
#     '2016-09-29',
#     '2016-10-15',
#     '2016-10-31',
#     '2016-11-16',
#     '2016-12-02',
#     '2016-12-18',
#     '2017-01-01',
#     '2017-01-17',
#     '2017-02-02',
#     '2017-02-18',
#     '2017-03-06',
#     '2017-03-22',
#     '2017-04-07',
#     '2017-04-23',
#     '2017-05-09',
#     '2017-05-25',
#     '2017-06-10',
#     '2017-06-26',
#     '2017-07-12',
#     '2017-07-28',
#     '2017-08-13',
#     '2017-08-29',
#     '2017-09-14',
#     '2017-09-30',
#     '2017-10-16',
#     '2017-11-01',
#     '2017-11-17',
#     '2017-12-03',
#     '2017-12-19',
#     '2018-01-01',
#     '2018-01-17',
#     '2018-02-02',
#     '2018-02-18',
#     '2018-03-06',
#     '2018-03-22',
#     '2018-04-07',
#     '2018-04-23',
#     '2018-05-09',
#     '2018-05-25',
#     '2018-06-10',
#     '2018-06-26',
#     '2018-07-12',
#     '2018-07-28',
#     '2018-08-13',
#     '2018-08-29',
#     '2018-09-14',
#     '2018-09-30',
#     '2018-10-16',
#     '2018-11-01',
#     '2018-11-17',
#     '2018-12-03',
#     '2018-12-19',
#     '2019-01-01',
#     '2019-01-17',
#     '2019-02-02',
#     '2019-02-18',
#     '2019-03-06',
#     '2019-03-22',
#     '2019-04-07',
#     '2019-04-23',
#     '2019-05-09',
#     '2019-05-25',
#     '2019-06-10',
#     '2019-06-26',
#     '2019-07-12',
#     '2019-07-28',
#     '2019-08-13',
#     '2019-08-29',
#     '2019-09-14',
#     '2019-09-30',
#     '2019-10-16',
#     '2019-11-01',
#     '2019-11-17',
#     '2019-12-03',
#     '2019-12-19',
#     '2020-01-01',
#     '2020-01-17',
#     '2020-02-02',
#     '2020-02-18',
#     '2020-03-05',
#     '2020-03-21',
#     '2020-04-06',
#     '2020-04-22',
#     '2020-05-08',
#     '2020-05-24',
#     '2020-06-09',
#     '2020-06-25',
#     '2020-07-11',
#     '2020-07-27',
#     '2020-08-12',
#     '2020-08-28',
#     '2020-09-13',
#     '2020-09-29',
#     '2020-10-15',
#     '2020-10-31',
#     '2020-11-16',
#     '2020-12-02',
#     '2020-12-18',
#     '2021-01-01',
#     '2021-01-17',
#     '2021-02-02',
#     '2021-02-18',
#     '2021-03-06',
#     '2021-03-22']},
#   'bands': {'type': 'bands',
#    'values': ['view_zenith_angle',
#     'sun_zenith_angle',
#     'pixel_reliability',
#     'relative_azimuth_angle',
#     'blue_reflectance',
#     'red_reflectance',
#     'NIR_reflectance',
#     'MIR_reflectance',
#     'NDVI',
#     'EVI',
#     'VI_Quality',
#     'composite_day_of_the_year']}},
#  'bdc:crs': '+proj=sinu +lon_0=0 +x_0=0 +y_0=0 +a=6371007.181 +b=6371007.181 +units=m +no_defs ',
#  'bdc:temporal_composition': {'step': '16',
#   'unit': 'day',
#   'cycle': {'step': 1, 'unit': 'year'},
#   'schema': 'cyclic'},
#  'links': [{'href': 'https://brazildatacube.dpi.inpe.br/stac/collections/MOD13Q1-6?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#    'rel': 'self',
#    'type': 'application/json',
#    'title': 'Link to this document'},
#   {'href': 'https://brazildatacube.dpi.inpe.br/stac/collections/MOD13Q1-6/items?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#    'rel': 'items',
#    'type': 'application/json',
#    'title': 'Items of the collection MOD13Q1-6'},
#   {'href': 'https://brazildatacube.dpi.inpe.br/stac/collections?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#    'rel': 'parent',
#    'type': 'application/json',
#    'title': 'Link to catalog collections'},
#   {'href': 'https://brazildatacube.dpi.inpe.br/stac/?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#    'rel': 'root',
#    'type': 'application/json',
#    'title': 'API landing page (root catalog)'}]}

# %%
collection.get_items()
# Out:
# {'stac_version': '0.9.0',
#  'stac_extensions': ['checksum', 'commons', 'context', 'eo'],
#  'type': 'FeatureCollection',
#  'links': [{'href': 'https://brazildatacube.dpi.inpe.br/stac/collections/MOD13Q1-6/items?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N&page=2',
#    'rel': 'next'}],
#  'context': {'matched': 8739, 'returned': 10, 'limit': 10},
#  'features': [{'type': 'Feature',
#    'id': 'MOD13Q1.A2021081.h10v09.006.2021098004954',
#    'collection': 'MOD13Q1-6',
#    'stac_version': '0.9.0',
#    'stac_extensions': ['checksum', 'commons', 'eo'],
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-71.079863, -10],
#       [-70, 0],
#       [-80, 0],
#       [-81.234129, -10],
#       [-71.079863, -10]]]},
#    'bbox': [-81.234129, -10.0, -70.0, 0.0],
#    'properties': {'bdc:tiles': ['010009'],
#     'datetime': '2021-03-22T00:00:00',
#     'start_datetime': '2021-03-22T00:00:00',
#     'end_datetime': '2021-03-22T00:00:00',
#     'created': '2021-05-01T09:04:30',
#     'updated': '2021-05-01T09:04:30',
#     'eo:gsd': 250.0,
#     'eo:bands': [{'name': 'view_zenith_angle',
#       'common_name': '',
#       'description': 'View zenith angle of VI Pixel',
#       'min': 0.0,
#       'max': 18000.0,
#       'nodata': -10000.0,
#       'scale': 0.01,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'sun_zenith_angle',
#       'common_name': '',
#       'description': 'Sun zenith angle of VI pixel',
#       'min': 0.0,
#       'max': 18000.0,
#       'nodata': -10000.0,
#       'scale': 0.01,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'pixel_reliability',
#       'common_name': 'quality',
#       'description': 'Quality reliability of VI pixel',
#       'min': 0.0,
#       'max': 3.0,
#       'nodata': -1.0,
#       'scale': 1.0,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'relative_azimuth_angle',
#       'common_name': '',
#       'description': 'Relative azimuth angle of VI pixel',
#       'min': -18000.0,
#       'max': 18000.0,
#       'nodata': -10000.0,
#       'scale': 0.01,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'blue_reflectance',
#       'common_name': 'blue',
#       'description': 'Surface Reflectance Band 3',
#       'min': 0.0,
#       'max': 10000.0,
#       'nodata': -1000.0,
#       'scale': 0.0001,
#       'center_wavelength': 0.469,
#       'full_width_half_max': 0.01,
#       'data_type': 'int16'},
#      {'name': 'red_reflectance',
#       'common_name': 'red',
#       'description': 'Surface Reflectance Band 1',
#       'min': 0.0,
#       'max': 10000.0,
#       'nodata': -1000.0,
#       'scale': 0.0001,
#       'center_wavelength': 0.645,
#       'full_width_half_max': 0.025,
#       'data_type': 'int16'},
#      {'name': 'NIR_reflectance',
#       'common_name': 'nir',
#       'description': 'Surface Reflectance Band 2',
#       'min': 0.0,
#       'max': 10000.0,
#       'nodata': -1000.0,
#       'scale': 0.0001,
#       'center_wavelength': 0.8585,
#       'full_width_half_max': 0.175,
#       'data_type': 'int16'},
#      {'name': 'MIR_reflectance',
#       'common_name': 'swir22',
#       'description': 'Surface Reflectance Band 7',
#       'min': 0.0,
#       'max': 10000.0,
#       'nodata': -1000.0,
#       'scale': 0.0001,
#       'center_wavelength': 0.213,
#       'full_width_half_max': 0.0025,
#       'data_type': 'int16'},
#      {'name': 'NDVI',
#       'common_name': 'NDVI',
#       'description': '16 day NDVI',
#       'min': -2000.0,
#       'max': 10000.0,
#       'nodata': -3000.0,
#       'scale': 0.0001,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'EVI',
#       'common_name': 'EVI',
#       'description': '16 day EVI',
#       'min': -2000.0,
#       'max': 10000.0,
#       'nodata': -3000.0,
#       'scale': 0.0001,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'VI_Quality',
#       'common_name': 'quality',
#       'description': 'VI quality indicators',
#       'min': 0.0,
#       'max': 65534.0,
#       'nodata': 65535.0,
#       'scale': 1.0,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'uint16'},
#      {'name': 'composite_day_of_the_year',
#       'common_name': 'quality',
#       'description': 'Day of year VI pixel',
#       'min': 1.0,
#       'max': 366.0,
#       'nodata': -1.0,
#       'scale': 1.0,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'}],
#     'eo:cloud_cover': 69.0,
#     'instruments': ['MODIS'],
#     'platform': 'TERRA'},
#    'assets': {'EVI': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h10/v09/2021/MOD13Q1.A2021081.h10v09.006.2021098004954/MOD13Q1.A2021081.h10v09.006.2021098004954_EVI.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-01T09:01:50',
#      'updated': '2021-05-01T09:01:50',
#      'bdc:size': 47158799,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '12207c901b73b552ab91c76e5b2525489dc9e0c08afe300583ed9b894cabc077af68',
#      'eo:bands': [9]},
#     'NDVI': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h10/v09/2021/MOD13Q1.A2021081.h10v09.006.2021098004954/MOD13Q1.A2021081.h10v09.006.2021098004954_NDVI.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-01T09:01:37',
#      'updated': '2021-05-01T09:01:37',
#      'bdc:size': 47398070,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220a1c3da95c94a25eb02eea0edc27c227f534e3b31380f3d2b8c5251f8a62dd9b5',
#      'eo:bands': [8]},
#     'thumbnail': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h10/v09/2021/MOD13Q1.A2021081.h10v09.006.2021098004954/MOD13Q1.A2021081.h10v09.006.2021098004954.png?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/png',
#      'roles': ['thumbnail'],
#      'created': '2021-05-01T09:04:30',
#      'updated': '2021-05-01T09:04:30',
#      'bdc:size': 1259578,
#      'checksum:multihash': '1220b723689989c27ec41bcab283363bd0fcf4256d45df1e89d4fe4db7412bdbdb72'},
#     'MIR_reflectance': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h10/v09/2021/MOD13Q1.A2021081.h10v09.006.2021098004954/MOD13Q1.A2021081.h10v09.006.2021098004954_MIR_reflectance.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-01T09:03:14',
#      'updated': '2021-05-01T09:03:14',
#      'bdc:size': 22977442,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '12207f7b5c466c3e6644f39c91feec24f09fe75965d009c85a68d6907cc8b8b2f162',
#      'eo:bands': [7]},
#     'NIR_reflectance': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h10/v09/2021/MOD13Q1.A2021081.h10v09.006.2021098004954/MOD13Q1.A2021081.h10v09.006.2021098004954_NIR_reflectance.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-01T09:02:38',
#      'updated': '2021-05-01T09:02:38',
#      'bdc:size': 44301412,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '122004be2539fabebf9c621ef25ce830d44146e1eb46f66aaa95bb151e2b54f58612',
#      'eo:bands': [6]},
#     'red_reflectance': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h10/v09/2021/MOD13Q1.A2021081.h10v09.006.2021098004954/MOD13Q1.A2021081.h10v09.006.2021098004954_red_reflectance.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-01T09:02:21',
#      'updated': '2021-05-01T09:02:21',
#      'bdc:size': 43060205,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220d39741ed1ad2b214f9198c35ad7adf38543becba0e9495d7f97820637c9cc0c4',
#      'eo:bands': [5]},
#     'blue_reflectance': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h10/v09/2021/MOD13Q1.A2021081.h10v09.006.2021098004954/MOD13Q1.A2021081.h10v09.006.2021098004954_blue_reflectance.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-01T09:02:59',
#      'updated': '2021-05-01T09:02:59',
#      'bdc:size': 23606161,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220dd67674f3123a5decbd993f877e907760f3d5066c4f27daf38dd9d8e34e4bc20',
#      'eo:bands': [4]},
#     'sun_zenith_angle': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h10/v09/2021/MOD13Q1.A2021081.h10v09.006.2021098004954/MOD13Q1.A2021081.h10v09.006.2021098004954_sun_zenith_angle.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-01T09:03:42',
#      'updated': '2021-05-01T09:03:42',
#      'bdc:size': 11285300,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220eab7d933cc76a3d48fd3f6ddf5a10e91953c1d025d8c10007d6d6ba47b44d2c4',
#      'eo:bands': [1]},
#     'pixel_reliability': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h10/v09/2021/MOD13Q1.A2021081.h10v09.006.2021098004954/MOD13Q1.A2021081.h10v09.006.2021098004954_pixel_reliability.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-01T09:04:19',
#      'updated': '2021-05-01T09:04:19',
#      'bdc:size': 1513065,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220cf0aa983fe7add1508ba59f6a7b99be767bb7c4a6bce06e5abbfec58d3978728',
#      'eo:bands': [2]},
#     'view_zenith_angle': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h10/v09/2021/MOD13Q1.A2021081.h10v09.006.2021098004954/MOD13Q1.A2021081.h10v09.006.2021098004954_view_zenith_angle.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-01T09:03:28',
#      'updated': '2021-05-01T09:03:28',
#      'bdc:size': 11348976,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220d1e36e0d6bd68b054dd1aa0e01e2e5f401cc74743ab9c2432bd727147268fbca',
#      'eo:bands': [0]},
#     'relative_azimuth_angle': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h10/v09/2021/MOD13Q1.A2021081.h10v09.006.2021098004954/MOD13Q1.A2021081.h10v09.006.2021098004954_relative_azimuth_angle.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-01T09:03:56',
#      'updated': '2021-05-01T09:03:56',
#      'bdc:size': 15417385,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '122049ec0c7f4ec71ec801143fdc94dcddc7090d49f97a82bbf0b7f41e5523fb5705',
#      'eo:bands': [3]}},
#    'links': [{'href': 'https://brazildatacube.dpi.inpe.br/stac/collections/MOD13Q1-6/items/MOD13Q1.A2021081.h10v09.006.2021098004954?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': 'Link to this document'},
#     {'href': 'https://brazildatacube.dpi.inpe.br/stac/collections/MOD13Q1-6?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'rel': 'parent',
#      'type': 'application/json',
#      'title': 'The collection related to this item'},
#     {'href': 'https://brazildatacube.dpi.inpe.br/stac/collections/MOD13Q1-6?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'rel': 'collection',
#      'type': 'application/json',
#      'title': 'The collection related to this item'},
#     {'href': 'https://brazildatacube.dpi.inpe.br/stac/',
#      'rel': 'root',
#      'type': 'application/json',
#      'title': 'API landing page (root catalog)'}]},
#   {'type': 'Feature',
#    'id': 'MOD13Q1.A2021081.h11v09.006.2021098015012',
#    'collection': 'MOD13Q1-6',
#    'stac_version': '0.9.0',
#    'stac_extensions': ['checksum', 'commons', 'eo'],
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-60.925597, -10],
#       [-60, 0],
#       [-70, 0],
#       [-71.079863, -10],
#       [-60.925597, -10]]]},
#    'bbox': [-71.079863, -10.0, -60.0, 0.0],
#    'properties': {'bdc:tiles': ['011009'],
#     'datetime': '2021-03-22T00:00:00',
#     'start_datetime': '2021-03-22T00:00:00',
#     'end_datetime': '2021-03-22T00:00:00',
#     'created': '2021-05-01T22:44:42',
#     'updated': '2021-05-01T22:44:42',
#     'eo:gsd': 250.0,
#     'eo:bands': [{'name': 'view_zenith_angle',
#       'common_name': '',
#       'description': 'View zenith angle of VI Pixel',
#       'min': 0.0,
#       'max': 18000.0,
#       'nodata': -10000.0,
#       'scale': 0.01,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'sun_zenith_angle',
#       'common_name': '',
#       'description': 'Sun zenith angle of VI pixel',
#       'min': 0.0,
#       'max': 18000.0,
#       'nodata': -10000.0,
#       'scale': 0.01,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'pixel_reliability',
#       'common_name': 'quality',
#       'description': 'Quality reliability of VI pixel',
#       'min': 0.0,
#       'max': 3.0,
#       'nodata': -1.0,
#       'scale': 1.0,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'relative_azimuth_angle',
#       'common_name': '',
#       'description': 'Relative azimuth angle of VI pixel',
#       'min': -18000.0,
#       'max': 18000.0,
#       'nodata': -10000.0,
#       'scale': 0.01,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'blue_reflectance',
#       'common_name': 'blue',
#       'description': 'Surface Reflectance Band 3',
#       'min': 0.0,
#       'max': 10000.0,
#       'nodata': -1000.0,
#       'scale': 0.0001,
#       'center_wavelength': 0.469,
#       'full_width_half_max': 0.01,
#       'data_type': 'int16'},
#      {'name': 'red_reflectance',
#       'common_name': 'red',
#       'description': 'Surface Reflectance Band 1',
#       'min': 0.0,
#       'max': 10000.0,
#       'nodata': -1000.0,
#       'scale': 0.0001,
#       'center_wavelength': 0.645,
#       'full_width_half_max': 0.025,
#       'data_type': 'int16'},
#      {'name': 'NIR_reflectance',
#       'common_name': 'nir',
#       'description': 'Surface Reflectance Band 2',
#       'min': 0.0,
#       'max': 10000.0,
#       'nodata': -1000.0,
#       'scale': 0.0001,
#       'center_wavelength': 0.8585,
#       'full_width_half_max': 0.175,
#       'data_type': 'int16'},
#      {'name': 'MIR_reflectance',
#       'common_name': 'swir22',
#       'description': 'Surface Reflectance Band 7',
#       'min': 0.0,
#       'max': 10000.0,
#       'nodata': -1000.0,
#       'scale': 0.0001,
#       'center_wavelength': 0.213,
#       'full_width_half_max': 0.0025,
#       'data_type': 'int16'},
#      {'name': 'NDVI',
#       'common_name': 'NDVI',
#       'description': '16 day NDVI',
#       'min': -2000.0,
#       'max': 10000.0,
#       'nodata': -3000.0,
#       'scale': 0.0001,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'EVI',
#       'common_name': 'EVI',
#       'description': '16 day EVI',
#       'min': -2000.0,
#       'max': 10000.0,
#       'nodata': -3000.0,
#       'scale': 0.0001,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'VI_Quality',
#       'common_name': 'quality',
#       'description': 'VI quality indicators',
#       'min': 0.0,
#       'max': 65534.0,
#       'nodata': 65535.0,
#       'scale': 1.0,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'uint16'},
#      {'name': 'composite_day_of_the_year',
#       'common_name': 'quality',
#       'description': 'Day of year VI pixel',
#       'min': 1.0,
#       'max': 366.0,
#       'nodata': -1.0,
#       'scale': 1.0,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'}],
#     'eo:cloud_cover': 57.0,
#     'instruments': ['MODIS'],
#     'platform': 'TERRA'},
#    'assets': {'EVI': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h11/v09/2021/MOD13Q1.A2021081.h11v09.006.2021098015012/MOD13Q1.A2021081.h11v09.006.2021098015012_EVI.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-01T22:42:50',
#      'updated': '2021-05-01T22:42:50',
#      'bdc:size': 49904815,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220a4daeb64bafcb58f511e91f7882870bb9f6aeb4cc6c4d8479fc79358adc53120',
#      'eo:bands': [9]},
#     'NDVI': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h11/v09/2021/MOD13Q1.A2021081.h11v09.006.2021098015012/MOD13Q1.A2021081.h11v09.006.2021098015012_NDVI.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-01T22:42:38',
#      'updated': '2021-05-01T22:42:38',
#      'bdc:size': 49554473,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '12201a85a1ddae09f837a254961bc5c2f07294941bb5f1bb8da7553acda6f47e8ed5',
#      'eo:bands': [8]},
#     'thumbnail': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h11/v09/2021/MOD13Q1.A2021081.h11v09.006.2021098015012/MOD13Q1.A2021081.h11v09.006.2021098015012.png?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/png',
#      'roles': ['thumbnail'],
#      'created': '2021-05-01T22:44:42',
#      'updated': '2021-05-01T22:44:42',
#      'bdc:size': 1390268,
#      'checksum:multihash': '12204ace0c28300a99c1fcbbf2a49ae43f24094b6ede9b902b441fdc3cd86482e926'},
#     'MIR_reflectance': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h11/v09/2021/MOD13Q1.A2021081.h11v09.006.2021098015012/MOD13Q1.A2021081.h11v09.006.2021098015012_MIR_reflectance.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-01T22:43:46',
#      'updated': '2021-05-01T22:43:46',
#      'bdc:size': 23265999,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220ee0e1f42e0a726084b4b397bb38649e1617366ecbc25d917521c24e822887e1e',
#      'eo:bands': [7]},
#     'NIR_reflectance': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h11/v09/2021/MOD13Q1.A2021081.h11v09.006.2021098015012/MOD13Q1.A2021081.h11v09.006.2021098015012_NIR_reflectance.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-01T22:43:22',
#      'updated': '2021-05-01T22:43:22',
#      'bdc:size': 46252655,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220b32202e60483e8d7e13a671a5fde2c8c0aef7c7304d0c5c1c3874681f13f87b7',
#      'eo:bands': [6]},
#     'red_reflectance': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h11/v09/2021/MOD13Q1.A2021081.h11v09.006.2021098015012/MOD13Q1.A2021081.h11v09.006.2021098015012_red_reflectance.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-01T22:43:11',
#      'updated': '2021-05-01T22:43:11',
#      'bdc:size': 43233383,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220e1353aa927c4f1c1f4f54a9a061a5027fbb9d2ae1dfe02ce864a89821d4766a6',
#      'eo:bands': [5]},
#     'blue_reflectance': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h11/v09/2021/MOD13Q1.A2021081.h11v09.006.2021098015012/MOD13Q1.A2021081.h11v09.006.2021098015012_blue_reflectance.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-01T22:43:33',
#      'updated': '2021-05-01T22:43:33',
#      'bdc:size': 23359095,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220ae7fb2bee243abed04a0af9b7cef070ea3e2d8c06677c28a211aa2e49e2f905f',
#      'eo:bands': [4]},
#     'sun_zenith_angle': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h11/v09/2021/MOD13Q1.A2021081.h11v09.006.2021098015012/MOD13Q1.A2021081.h11v09.006.2021098015012_sun_zenith_angle.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-01T22:44:05',
#      'updated': '2021-05-01T22:44:05',
#      'bdc:size': 11849880,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220a18ad42271f824fe17f53f6db49ecb1f06fefaffa7c4a0e66a3ca618350f7232',
#      'eo:bands': [1]},
#     'pixel_reliability': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h11/v09/2021/MOD13Q1.A2021081.h11v09.006.2021098015012/MOD13Q1.A2021081.h11v09.006.2021098015012_pixel_reliability.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-01T22:44:32',
#      'updated': '2021-05-01T22:44:32',
#      'bdc:size': 1798143,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220e286850231af99f064251f940454bf6848f6e33fda64f924018501b4d4a676d1',
#      'eo:bands': [2]},
#     'view_zenith_angle': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h11/v09/2021/MOD13Q1.A2021081.h11v09.006.2021098015012/MOD13Q1.A2021081.h11v09.006.2021098015012_view_zenith_angle.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-01T22:43:55',
#      'updated': '2021-05-01T22:43:55',
#      'bdc:size': 11789806,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220ee9112b4151a883390556f3777a158b7d18704a0180fe177d06570f5fbf14ad8',
#      'eo:bands': [0]},
#     'relative_azimuth_angle': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h11/v09/2021/MOD13Q1.A2021081.h11v09.006.2021098015012/MOD13Q1.A2021081.h11v09.006.2021098015012_relative_azimuth_angle.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-01T22:44:16',
#      'updated': '2021-05-01T22:44:16',
#      'bdc:size': 16170108,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220e3c111a603be30c7271de50e53d18bce0dd181acf2c55f77b06bfbf0d5699d13',
#      'eo:bands': [3]}},
#    'links': [{'href': 'https://brazildatacube.dpi.inpe.br/stac/collections/MOD13Q1-6/items/MOD13Q1.A2021081.h11v09.006.2021098015012?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': 'Link to this document'},
#     {'href': 'https://brazildatacube.dpi.inpe.br/stac/collections/MOD13Q1-6?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'rel': 'parent',
#      'type': 'application/json',
#      'title': 'The collection related to this item'},
#     {'href': 'https://brazildatacube.dpi.inpe.br/stac/collections/MOD13Q1-6?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'rel': 'collection',
#      'type': 'application/json',
#      'title': 'The collection related to this item'},
#     {'href': 'https://brazildatacube.dpi.inpe.br/stac/',
#      'rel': 'root',
#      'type': 'application/json',
#      'title': 'API landing page (root catalog)'}]},
#   {'type': 'Feature',
#    'id': 'MOD13Q1.A2021081.h11v10.006.2021098003734',
#    'collection': 'MOD13Q1-6',
#    'stac_version': '0.9.0',
#    'stac_extensions': ['checksum', 'commons', 'eo'],
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-63.850666, -20],
#       [-60.925597, -10],
#       [-71.079863, -10],
#       [-74.492444, -20],
#       [-63.850666, -20]]]},
#    'bbox': [-74.492444, -20.0, -60.925597, -10.0],
#    'properties': {'bdc:tiles': ['011010'],
#     'datetime': '2021-03-22T00:00:00',
#     'start_datetime': '2021-03-22T00:00:00',
#     'end_datetime': '2021-03-22T00:00:00',
#     'created': '2021-05-02T04:36:24',
#     'updated': '2021-05-02T04:36:24',
#     'eo:gsd': 250.0,
#     'eo:bands': [{'name': 'view_zenith_angle',
#       'common_name': '',
#       'description': 'View zenith angle of VI Pixel',
#       'min': 0.0,
#       'max': 18000.0,
#       'nodata': -10000.0,
#       'scale': 0.01,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'sun_zenith_angle',
#       'common_name': '',
#       'description': 'Sun zenith angle of VI pixel',
#       'min': 0.0,
#       'max': 18000.0,
#       'nodata': -10000.0,
#       'scale': 0.01,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'pixel_reliability',
#       'common_name': 'quality',
#       'description': 'Quality reliability of VI pixel',
#       'min': 0.0,
#       'max': 3.0,
#       'nodata': -1.0,
#       'scale': 1.0,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'relative_azimuth_angle',
#       'common_name': '',
#       'description': 'Relative azimuth angle of VI pixel',
#       'min': -18000.0,
#       'max': 18000.0,
#       'nodata': -10000.0,
#       'scale': 0.01,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'blue_reflectance',
#       'common_name': 'blue',
#       'description': 'Surface Reflectance Band 3',
#       'min': 0.0,
#       'max': 10000.0,
#       'nodata': -1000.0,
#       'scale': 0.0001,
#       'center_wavelength': 0.469,
#       'full_width_half_max': 0.01,
#       'data_type': 'int16'},
#      {'name': 'red_reflectance',
#       'common_name': 'red',
#       'description': 'Surface Reflectance Band 1',
#       'min': 0.0,
#       'max': 10000.0,
#       'nodata': -1000.0,
#       'scale': 0.0001,
#       'center_wavelength': 0.645,
#       'full_width_half_max': 0.025,
#       'data_type': 'int16'},
#      {'name': 'NIR_reflectance',
#       'common_name': 'nir',
#       'description': 'Surface Reflectance Band 2',
#       'min': 0.0,
#       'max': 10000.0,
#       'nodata': -1000.0,
#       'scale': 0.0001,
#       'center_wavelength': 0.8585,
#       'full_width_half_max': 0.175,
#       'data_type': 'int16'},
#      {'name': 'MIR_reflectance',
#       'common_name': 'swir22',
#       'description': 'Surface Reflectance Band 7',
#       'min': 0.0,
#       'max': 10000.0,
#       'nodata': -1000.0,
#       'scale': 0.0001,
#       'center_wavelength': 0.213,
#       'full_width_half_max': 0.0025,
#       'data_type': 'int16'},
#      {'name': 'NDVI',
#       'common_name': 'NDVI',
#       'description': '16 day NDVI',
#       'min': -2000.0,
#       'max': 10000.0,
#       'nodata': -3000.0,
#       'scale': 0.0001,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'EVI',
#       'common_name': 'EVI',
#       'description': '16 day EVI',
#       'min': -2000.0,
#       'max': 10000.0,
#       'nodata': -3000.0,
#       'scale': 0.0001,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'VI_Quality',
#       'common_name': 'quality',
#       'description': 'VI quality indicators',
#       'min': 0.0,
#       'max': 65534.0,
#       'nodata': 65535.0,
#       'scale': 1.0,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'uint16'},
#      {'name': 'composite_day_of_the_year',
#       'common_name': 'quality',
#       'description': 'Day of year VI pixel',
#       'min': 1.0,
#       'max': 366.0,
#       'nodata': -1.0,
#       'scale': 1.0,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'}],
#     'eo:cloud_cover': 41.0,
#     'instruments': ['MODIS'],
#     'platform': 'TERRA'},
#    'assets': {'EVI': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h11/v10/2021/MOD13Q1.A2021081.h11v10.006.2021098003734/MOD13Q1.A2021081.h11v10.006.2021098003734_EVI.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-02T04:35:13',
#      'updated': '2021-05-02T04:35:13',
#      'bdc:size': 44945330,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '12206b94596353f486ea40a68b0d9efa847eaec17fb140b1d80de03b249d29388e8c',
#      'eo:bands': [9]},
#     'NDVI': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h11/v10/2021/MOD13Q1.A2021081.h11v10.006.2021098003734/MOD13Q1.A2021081.h11v10.006.2021098003734_NDVI.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-02T04:35:05',
#      'updated': '2021-05-02T04:35:05',
#      'bdc:size': 44871125,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '122078a4c40d8068f3885961373906472f4f0ba99334f1f1955f3b5601513ace79c8',
#      'eo:bands': [8]},
#     'thumbnail': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h11/v10/2021/MOD13Q1.A2021081.h11v10.006.2021098003734/MOD13Q1.A2021081.h11v10.006.2021098003734.png?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/png',
#      'roles': ['thumbnail'],
#      'created': '2021-05-02T04:36:24',
#      'updated': '2021-05-02T04:36:24',
#      'bdc:size': 1172014,
#      'checksum:multihash': '12202403f4dedaf8a60c56fe59d98be2f9d0ee9089851655826e47b84cf9519ced0a'},
#     'MIR_reflectance': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h11/v10/2021/MOD13Q1.A2021081.h11v10.006.2021098003734/MOD13Q1.A2021081.h11v10.006.2021098003734_MIR_reflectance.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-02T04:35:45',
#      'updated': '2021-05-02T04:35:45',
#      'bdc:size': 21970529,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '12201930a93b199a5a30eeecb9d2e3cba890dfda8f9a0d5b03efc6e6207413c12506',
#      'eo:bands': [7]},
#     'NIR_reflectance': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h11/v10/2021/MOD13Q1.A2021081.h11v10.006.2021098003734/MOD13Q1.A2021081.h11v10.006.2021098003734_NIR_reflectance.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-02T04:35:33',
#      'updated': '2021-05-02T04:35:33',
#      'bdc:size': 42884302,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '12200c0caca9344bb36636aadeb6a38e515cb03ccfe40ba8a7d6f4a85a956bb6aa20',
#      'eo:bands': [6]},
#     'red_reflectance': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h11/v10/2021/MOD13Q1.A2021081.h11v10.006.2021098003734/MOD13Q1.A2021081.h11v10.006.2021098003734_red_reflectance.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-02T04:35:27',
#      'updated': '2021-05-02T04:35:27',
#      'bdc:size': 40352071,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '12204ca1d8e75d83d183e82564ea261ecf2c60e0842c84333e62043f64ba0c7caae0',
#      'eo:bands': [5]},
#     'blue_reflectance': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h11/v10/2021/MOD13Q1.A2021081.h11v10.006.2021098003734/MOD13Q1.A2021081.h11v10.006.2021098003734_blue_reflectance.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-02T04:35:39',
#      'updated': '2021-05-02T04:35:39',
#      'bdc:size': 21619108,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220929bfc9301a7eef321dee53098b33467d7a21529e99557c801d2fa9ee736f2b7',
#      'eo:bands': [4]},
#     'sun_zenith_angle': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h11/v10/2021/MOD13Q1.A2021081.h11v10.006.2021098003734/MOD13Q1.A2021081.h11v10.006.2021098003734_sun_zenith_angle.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-02T04:35:58',
#      'updated': '2021-05-02T04:35:58',
#      'bdc:size': 10857276,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '122004a89b8801c0f508e8efa75abf026a4f7be7add05fd30b73241f5716db77334b',
#      'eo:bands': [1]},
#     'pixel_reliability': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h11/v10/2021/MOD13Q1.A2021081.h11v10.006.2021098003734/MOD13Q1.A2021081.h11v10.006.2021098003734_pixel_reliability.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-02T04:36:16',
#      'updated': '2021-05-02T04:36:16',
#      'bdc:size': 1699635,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '12207144c5739aff783a5d613b6a2b7be225cb7a8e946aa21c4cc9fa510b3b045b53',
#      'eo:bands': [2]},
#     'view_zenith_angle': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h11/v10/2021/MOD13Q1.A2021081.h11v10.006.2021098003734/MOD13Q1.A2021081.h11v10.006.2021098003734_view_zenith_angle.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-02T04:35:52',
#      'updated': '2021-05-02T04:35:52',
#      'bdc:size': 11358349,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220787180b8c198c0092876b3806ef6994b9650c06202331f411b99593c01d5e5b5',
#      'eo:bands': [0]},
#     'relative_azimuth_angle': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h11/v10/2021/MOD13Q1.A2021081.h11v10.006.2021098003734/MOD13Q1.A2021081.h11v10.006.2021098003734_relative_azimuth_angle.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-02T04:36:04',
#      'updated': '2021-05-02T04:36:04',
#      'bdc:size': 14970801,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '122082f1ac93385e66675f93bb290d2a54fff11d670414104054cef5e17152d5bbdd',
#      'eo:bands': [3]}},
#    'links': [{'href': 'https://brazildatacube.dpi.inpe.br/stac/collections/MOD13Q1-6/items/MOD13Q1.A2021081.h11v10.006.2021098003734?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': 'Link to this document'},
#     {'href': 'https://brazildatacube.dpi.inpe.br/stac/collections/MOD13Q1-6?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'rel': 'parent',
#      'type': 'application/json',
#      'title': 'The collection related to this item'},
#     {'href': 'https://brazildatacube.dpi.inpe.br/stac/collections/MOD13Q1-6?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'rel': 'collection',
#      'type': 'application/json',
#      'title': 'The collection related to this item'},
#     {'href': 'https://brazildatacube.dpi.inpe.br/stac/',
#      'rel': 'root',
#      'type': 'application/json',
#      'title': 'API landing page (root catalog)'}]},
#   {'type': 'Feature',
#    'id': 'MOD13Q1.A2021081.h12v08.006.2021098012558',
#    'collection': 'MOD13Q1-6',
#    'stac_version': '0.9.0',
#    'stac_extensions': ['checksum', 'commons', 'eo'],
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-50, 0],
#       [-50.771331, 10],
#       [-60.925597, 10],
#       [-60, 0],
#       [-50, 0]]]},
#    'bbox': [-60.925597, 0.0, -50.0, 10.0],
#    'properties': {'bdc:tiles': ['012008'],
#     'datetime': '2021-03-22T00:00:00',
#     'start_datetime': '2021-03-22T00:00:00',
#     'end_datetime': '2021-03-22T00:00:00',
#     'created': '2021-05-02T08:38:42',
#     'updated': '2021-05-02T08:38:42',
#     'eo:gsd': 250.0,
#     'eo:bands': [{'name': 'view_zenith_angle',
#       'common_name': '',
#       'description': 'View zenith angle of VI Pixel',
#       'min': 0.0,
#       'max': 18000.0,
#       'nodata': -10000.0,
#       'scale': 0.01,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'sun_zenith_angle',
#       'common_name': '',
#       'description': 'Sun zenith angle of VI pixel',
#       'min': 0.0,
#       'max': 18000.0,
#       'nodata': -10000.0,
#       'scale': 0.01,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'pixel_reliability',
#       'common_name': 'quality',
#       'description': 'Quality reliability of VI pixel',
#       'min': 0.0,
#       'max': 3.0,
#       'nodata': -1.0,
#       'scale': 1.0,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'relative_azimuth_angle',
#       'common_name': '',
#       'description': 'Relative azimuth angle of VI pixel',
#       'min': -18000.0,
#       'max': 18000.0,
#       'nodata': -10000.0,
#       'scale': 0.01,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'blue_reflectance',
#       'common_name': 'blue',
#       'description': 'Surface Reflectance Band 3',
#       'min': 0.0,
#       'max': 10000.0,
#       'nodata': -1000.0,
#       'scale': 0.0001,
#       'center_wavelength': 0.469,
#       'full_width_half_max': 0.01,
#       'data_type': 'int16'},
#      {'name': 'red_reflectance',
#       'common_name': 'red',
#       'description': 'Surface Reflectance Band 1',
#       'min': 0.0,
#       'max': 10000.0,
#       'nodata': -1000.0,
#       'scale': 0.0001,
#       'center_wavelength': 0.645,
#       'full_width_half_max': 0.025,
#       'data_type': 'int16'},
#      {'name': 'NIR_reflectance',
#       'common_name': 'nir',
#       'description': 'Surface Reflectance Band 2',
#       'min': 0.0,
#       'max': 10000.0,
#       'nodata': -1000.0,
#       'scale': 0.0001,
#       'center_wavelength': 0.8585,
#       'full_width_half_max': 0.175,
#       'data_type': 'int16'},
#      {'name': 'MIR_reflectance',
#       'common_name': 'swir22',
#       'description': 'Surface Reflectance Band 7',
#       'min': 0.0,
#       'max': 10000.0,
#       'nodata': -1000.0,
#       'scale': 0.0001,
#       'center_wavelength': 0.213,
#       'full_width_half_max': 0.0025,
#       'data_type': 'int16'},
#      {'name': 'NDVI',
#       'common_name': 'NDVI',
#       'description': '16 day NDVI',
#       'min': -2000.0,
#       'max': 10000.0,
#       'nodata': -3000.0,
#       'scale': 0.0001,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'EVI',
#       'common_name': 'EVI',
#       'description': '16 day EVI',
#       'min': -2000.0,
#       'max': 10000.0,
#       'nodata': -3000.0,
#       'scale': 0.0001,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'VI_Quality',
#       'common_name': 'quality',
#       'description': 'VI quality indicators',
#       'min': 0.0,
#       'max': 65534.0,
#       'nodata': 65535.0,
#       'scale': 1.0,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'uint16'},
#      {'name': 'composite_day_of_the_year',
#       'common_name': 'quality',
#       'description': 'Day of year VI pixel',
#       'min': 1.0,
#       'max': 366.0,
#       'nodata': -1.0,
#       'scale': 1.0,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'}],
#     'eo:cloud_cover': 76.0,
#     'instruments': ['MODIS'],
#     'platform': 'TERRA'},
#    'assets': {'EVI': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h12/v08/2021/MOD13Q1.A2021081.h12v08.006.2021098012558/MOD13Q1.A2021081.h12v08.006.2021098012558_EVI.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-02T08:37:34',
#      'updated': '2021-05-02T08:37:34',
#      'bdc:size': 30102780,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220ad0740bdc79acfc4214857713dc98cfaa1011cfcecd27963c32d3124953ee37e',
#      'eo:bands': [9]},
#     'NDVI': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h12/v08/2021/MOD13Q1.A2021081.h12v08.006.2021098012558/MOD13Q1.A2021081.h12v08.006.2021098012558_NDVI.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-02T08:37:30',
#      'updated': '2021-05-02T08:37:30',
#      'bdc:size': 30473858,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '122052d40e1139bc7480dc43633b98ddd310ee9e6cb5f76fc3bf86631924ad2120bb',
#      'eo:bands': [8]},
#     'thumbnail': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h12/v08/2021/MOD13Q1.A2021081.h12v08.006.2021098012558/MOD13Q1.A2021081.h12v08.006.2021098012558.png?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/png',
#      'roles': ['thumbnail'],
#      'created': '2021-05-02T08:38:42',
#      'updated': '2021-05-02T08:38:42',
#      'bdc:size': 911984,
#      'checksum:multihash': '1220475c974b047e6ae13e672eede5f6e73dc7369a51e4bcdca0da54372b2456a238'},
#     'MIR_reflectance': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h12/v08/2021/MOD13Q1.A2021081.h12v08.006.2021098012558/MOD13Q1.A2021081.h12v08.006.2021098012558_MIR_reflectance.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-02T08:38:07',
#      'updated': '2021-05-02T08:38:07',
#      'bdc:size': 15170282,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '12201474822acaa35f649c8aad316dd98fd5298e9e1d0880943211ddb4c071aedbda',
#      'eo:bands': [7]},
#     'NIR_reflectance': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h12/v08/2021/MOD13Q1.A2021081.h12v08.006.2021098012558/MOD13Q1.A2021081.h12v08.006.2021098012558_NIR_reflectance.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-02T08:37:53',
#      'updated': '2021-05-02T08:37:53',
#      'bdc:size': 28383184,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '122048a5fc68d747a319dbc21d99a01cf503bc3396a49bc68090d4cacedad11dfbfb',
#      'eo:bands': [6]},
#     'red_reflectance': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h12/v08/2021/MOD13Q1.A2021081.h12v08.006.2021098012558/MOD13Q1.A2021081.h12v08.006.2021098012558_red_reflectance.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-02T08:37:47',
#      'updated': '2021-05-02T08:37:47',
#      'bdc:size': 27425185,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220e269d451a736876a08aab7fc3db5496c5564636232851a38e945b3d16483268f',
#      'eo:bands': [5]},
#     'blue_reflectance': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h12/v08/2021/MOD13Q1.A2021081.h12v08.006.2021098012558/MOD13Q1.A2021081.h12v08.006.2021098012558_blue_reflectance.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-02T08:38:01',
#      'updated': '2021-05-02T08:38:01',
#      'bdc:size': 15768898,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '12200c105ac920a1cba692f9adb41dc14a23d7e4842233a5ab585be60ff86aac969a',
#      'eo:bands': [4]},
#     'sun_zenith_angle': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h12/v08/2021/MOD13Q1.A2021081.h12v08.006.2021098012558/MOD13Q1.A2021081.h12v08.006.2021098012558_sun_zenith_angle.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-02T08:38:19',
#      'updated': '2021-05-02T08:38:19',
#      'bdc:size': 9556010,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220194cd661e83533dff8741c0b9eb6f1a43d8fcf4d405fb74ed984d729c2b48f7e',
#      'eo:bands': [1]},
# ...
#      'updated': '2021-05-03T00:40:50',
#      'bdc:size': 12967016,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220d247788e16ab3d2641d39bc97336be9a41b6ef5cf0bb98c3546874e182ce706d',
#      'eo:bands': [1]},
#     'pixel_reliability': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h13/v10/2021/MOD13Q1.A2021081.h13v10.006.2021098014817/MOD13Q1.A2021081.h13v10.006.2021098014817_pixel_reliability.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-03T00:41:01',
#      'updated': '2021-05-03T00:41:01',
#      'bdc:size': 501626,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220a5452327183acd57aa07196923375651c98981ee90a26bc0f07d46a0370dba48',
#      'eo:bands': [2]},
#     'view_zenith_angle': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h13/v10/2021/MOD13Q1.A2021081.h13v10.006.2021098014817/MOD13Q1.A2021081.h13v10.006.2021098014817_view_zenith_angle.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-03T00:40:46',
#      'updated': '2021-05-03T00:40:46',
#      'bdc:size': 14441616,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '12206ed3c457ff04482c65dba597f2ef4f0533db6fca88f200521ca567cc55a09f7d',
#      'eo:bands': [0]},
#     'relative_azimuth_angle': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h13/v10/2021/MOD13Q1.A2021081.h13v10.006.2021098014817/MOD13Q1.A2021081.h13v10.006.2021098014817_relative_azimuth_angle.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-03T00:40:54',
#      'updated': '2021-05-03T00:40:54',
#      'bdc:size': 19519997,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220ccee17b8e76f4b0c04ba32eab3d2414e2f429131127e0eb8331e2eafc6ceab20',
#      'eo:bands': [3]}},
#    'links': [{'href': 'https://brazildatacube.dpi.inpe.br/stac/collections/MOD13Q1-6/items/MOD13Q1.A2021081.h13v10.006.2021098014817?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': 'Link to this document'},
#     {'href': 'https://brazildatacube.dpi.inpe.br/stac/collections/MOD13Q1-6?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'rel': 'parent',
#      'type': 'application/json',
#      'title': 'The collection related to this item'},
#     {'href': 'https://brazildatacube.dpi.inpe.br/stac/collections/MOD13Q1-6?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'rel': 'collection',
#      'type': 'application/json',
#      'title': 'The collection related to this item'},
#     {'href': 'https://brazildatacube.dpi.inpe.br/stac/',
#      'rel': 'root',
#      'type': 'application/json',
#      'title': 'API landing page (root catalog)'}]},
#   {'type': 'Feature',
#    'id': 'MOD13Q1.A2021081.h13v11.006.2021098014644',
#    'collection': 'MOD13Q1-6',
#    'stac_version': '0.9.0',
#    'stac_extensions': ['checksum', 'commons', 'eo'],
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-46.188022, -30],
#       [-42.567111, -20],
#       [-53.208889, -20],
#       [-57.735027, -30],
#       [-46.188022, -30]]]},
#    'bbox': [-57.735027, -30.0, -42.567111, -20.0],
#    'properties': {'bdc:tiles': ['013011'],
#     'datetime': '2021-03-22T00:00:00',
#     'start_datetime': '2021-03-22T00:00:00',
#     'end_datetime': '2021-03-22T00:00:00',
#     'created': '2021-05-03T03:16:47',
#     'updated': '2021-05-03T03:16:47',
#     'eo:gsd': 250.0,
#     'eo:bands': [{'name': 'view_zenith_angle',
#       'common_name': '',
#       'description': 'View zenith angle of VI Pixel',
#       'min': 0.0,
#       'max': 18000.0,
#       'nodata': -10000.0,
#       'scale': 0.01,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'sun_zenith_angle',
#       'common_name': '',
#       'description': 'Sun zenith angle of VI pixel',
#       'min': 0.0,
#       'max': 18000.0,
#       'nodata': -10000.0,
#       'scale': 0.01,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'pixel_reliability',
#       'common_name': 'quality',
#       'description': 'Quality reliability of VI pixel',
#       'min': 0.0,
#       'max': 3.0,
#       'nodata': -1.0,
#       'scale': 1.0,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'relative_azimuth_angle',
#       'common_name': '',
#       'description': 'Relative azimuth angle of VI pixel',
#       'min': -18000.0,
#       'max': 18000.0,
#       'nodata': -10000.0,
#       'scale': 0.01,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'blue_reflectance',
#       'common_name': 'blue',
#       'description': 'Surface Reflectance Band 3',
#       'min': 0.0,
#       'max': 10000.0,
#       'nodata': -1000.0,
#       'scale': 0.0001,
#       'center_wavelength': 0.469,
#       'full_width_half_max': 0.01,
#       'data_type': 'int16'},
#      {'name': 'red_reflectance',
#       'common_name': 'red',
#       'description': 'Surface Reflectance Band 1',
#       'min': 0.0,
#       'max': 10000.0,
#       'nodata': -1000.0,
#       'scale': 0.0001,
#       'center_wavelength': 0.645,
#       'full_width_half_max': 0.025,
#       'data_type': 'int16'},
#      {'name': 'NIR_reflectance',
#       'common_name': 'nir',
#       'description': 'Surface Reflectance Band 2',
#       'min': 0.0,
#       'max': 10000.0,
#       'nodata': -1000.0,
#       'scale': 0.0001,
#       'center_wavelength': 0.8585,
#       'full_width_half_max': 0.175,
#       'data_type': 'int16'},
#      {'name': 'MIR_reflectance',
#       'common_name': 'swir22',
#       'description': 'Surface Reflectance Band 7',
#       'min': 0.0,
#       'max': 10000.0,
#       'nodata': -1000.0,
#       'scale': 0.0001,
#       'center_wavelength': 0.213,
#       'full_width_half_max': 0.0025,
#       'data_type': 'int16'},
#      {'name': 'NDVI',
#       'common_name': 'NDVI',
#       'description': '16 day NDVI',
#       'min': -2000.0,
#       'max': 10000.0,
#       'nodata': -3000.0,
#       'scale': 0.0001,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'EVI',
#       'common_name': 'EVI',
#       'description': '16 day EVI',
#       'min': -2000.0,
#       'max': 10000.0,
#       'nodata': -3000.0,
#       'scale': 0.0001,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'},
#      {'name': 'VI_Quality',
#       'common_name': 'quality',
#       'description': 'VI quality indicators',
#       'min': 0.0,
#       'max': 65534.0,
#       'nodata': 65535.0,
#       'scale': 1.0,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'uint16'},
#      {'name': 'composite_day_of_the_year',
#       'common_name': 'quality',
#       'description': 'Day of year VI pixel',
#       'min': 1.0,
#       'max': 366.0,
#       'nodata': -1.0,
#       'scale': 1.0,
#       'center_wavelength': None,
#       'full_width_half_max': None,
#       'data_type': 'int16'}],
#     'eo:cloud_cover': 1.0,
#     'instruments': ['MODIS'],
#     'platform': 'TERRA'},
#    'assets': {'EVI': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h13/v11/2021/MOD13Q1.A2021081.h13v11.006.2021098014644/MOD13Q1.A2021081.h13v11.006.2021098014644_EVI.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-03T03:16:01',
#      'updated': '2021-05-03T03:16:01',
#      'bdc:size': 40523736,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220807f7845d58e7ce48784d61f6b9383c318fd8415caf72a7cbfb33927d136f9c7',
#      'eo:bands': [9]},
#     'NDVI': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h13/v11/2021/MOD13Q1.A2021081.h13v11.006.2021098014644/MOD13Q1.A2021081.h13v11.006.2021098014644_NDVI.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-03T03:15:56',
#      'updated': '2021-05-03T03:15:56',
#      'bdc:size': 39828173,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '12201d432007cc8f9fb7742c0aa27cefa82a27c3ab185d050dfa0c7f1d090a0d52e3',
#      'eo:bands': [8]},
#     'thumbnail': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h13/v11/2021/MOD13Q1.A2021081.h13v11.006.2021098014644/MOD13Q1.A2021081.h13v11.006.2021098014644.png?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/png',
#      'roles': ['thumbnail'],
#      'created': '2021-05-03T03:16:47',
#      'updated': '2021-05-03T03:16:47',
#      'bdc:size': 1132225,
#      'checksum:multihash': '122014ff602ff8337e86158f294bde854735e9badaef0f0f6019b9d6ba2fc285f621'},
#     'MIR_reflectance': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h13/v11/2021/MOD13Q1.A2021081.h13v11.006.2021098014644/MOD13Q1.A2021081.h13v11.006.2021098014644_MIR_reflectance.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-03T03:16:22',
#      'updated': '2021-05-03T03:16:22',
#      'bdc:size': 22200228,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '122059c56573a5f3d5b22cf0b9dd72c067f5cfe38f33e0faadf8a5c3263b4f75d6aa',
#      'eo:bands': [7]},
#     'NIR_reflectance': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h13/v11/2021/MOD13Q1.A2021081.h13v11.006.2021098014644/MOD13Q1.A2021081.h13v11.006.2021098014644_NIR_reflectance.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-03T03:16:13',
#      'updated': '2021-05-03T03:16:13',
#      'bdc:size': 37379068,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220840ff61d690775f7d8553822a7aeb64c0b466017f7604ece00775e7fd2188560',
#      'eo:bands': [6]},
#     'red_reflectance': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h13/v11/2021/MOD13Q1.A2021081.h13v11.006.2021098014644/MOD13Q1.A2021081.h13v11.006.2021098014644_red_reflectance.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-03T03:16:09',
#      'updated': '2021-05-03T03:16:09',
#      'bdc:size': 33852520,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '12207a7196d7c892008214512bcc8fe01051af450ba3714647e803e6ab91fc045470',
#      'eo:bands': [5]},
#     'blue_reflectance': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h13/v11/2021/MOD13Q1.A2021081.h13v11.006.2021098014644/MOD13Q1.A2021081.h13v11.006.2021098014644_blue_reflectance.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-03T03:16:17',
#      'updated': '2021-05-03T03:16:17',
#      'bdc:size': 19189677,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '12205d1350aaa68ead77586a4c3507ac3fbcdc17a818da3cc888fde01b279939413e',
#      'eo:bands': [4]},
#     'sun_zenith_angle': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h13/v11/2021/MOD13Q1.A2021081.h13v11.006.2021098014644/MOD13Q1.A2021081.h13v11.006.2021098014644_sun_zenith_angle.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-03T03:16:30',
#      'updated': '2021-05-03T03:16:30',
#      'bdc:size': 9373579,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '122072296fcf3f4db39ece28b0f97e14d76fd2d3201596727ed678d5d368454988e3',
#      'eo:bands': [1]},
#     'pixel_reliability': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h13/v11/2021/MOD13Q1.A2021081.h13v11.006.2021098014644/MOD13Q1.A2021081.h13v11.006.2021098014644_pixel_reliability.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-03T03:16:40',
#      'updated': '2021-05-03T03:16:40',
#      'bdc:size': 589533,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '1220eb095cfc2b5901f9bc51023141102d21f8e6de122b2c7842f46d13bda6bfaf3e',
#      'eo:bands': [2]},
#     'view_zenith_angle': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h13/v11/2021/MOD13Q1.A2021081.h13v11.006.2021098014644/MOD13Q1.A2021081.h13v11.006.2021098014644_view_zenith_angle.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-03T03:16:26',
#      'updated': '2021-05-03T03:16:26',
#      'bdc:size': 10716287,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '12208f28a4c1b9355839f1a988fa3d1506fc530ebf9dc21bf3158441eaf8eef57d4a',
#      'eo:bands': [0]},
#     'relative_azimuth_angle': {'href': 'https://brazildatacube.dpi.inpe.br/data/d006/Mosaic/MOD13Q1/v006/h13/v11/2021/MOD13Q1.A2021081.h13v11.006.2021098014644/MOD13Q1.A2021081.h13v11.006.2021098014644_relative_azimuth_angle.tif?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'created': '2021-05-03T03:16:34',
#      'updated': '2021-05-03T03:16:34',
#      'bdc:size': 14242036,
#      'bdc:chunk_size': {'x': 512, 'y': 512},
#      'bdc:raster_size': {'x': 4800, 'y': 4800},
#      'checksum:multihash': '12201e064370fb8ebea5fcd56b76cac3280d46dd14b4ba7f525a3655dc9e9a6bddba',
#      'eo:bands': [3]}},
#    'links': [{'href': 'https://brazildatacube.dpi.inpe.br/stac/collections/MOD13Q1-6/items/MOD13Q1.A2021081.h13v11.006.2021098014644?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': 'Link to this document'},
#     {'href': 'https://brazildatacube.dpi.inpe.br/stac/collections/MOD13Q1-6?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'rel': 'parent',
#      'type': 'application/json',
#      'title': 'The collection related to this item'},
#     {'href': 'https://brazildatacube.dpi.inpe.br/stac/collections/MOD13Q1-6?access_token=ylU3VnEqoeK2oAij5Ln3S3FLMLaV7zTYaw64VHqd6N',
#      'rel': 'collection',
#      'type': 'application/json',
#      'title': 'The collection related to this item'},
#     {'href': 'https://brazildatacube.dpi.inpe.br/stac/',
#      'rel': 'root',
#      'type': 'application/json',
#      'title': 'API landing page (root catalog)'}]}]}

# %%
Datetimes = ['2010-10-01/2011-04-30', '2013-10-01/2014-04-30', '2015-10-01/2016-04-30',]

for date in Datetimes:
    items = collection.get_items(
            filter={
                'bbox':'-54.3494,-28.8928,-51.5259,-27.5375',
                'datetime': date,
                'limit':40
            }
    )
#     print(items)
    print(len(items.features))
    for i in range(0,len(items.features)):
        items.features[i].assets['NDVI'].download('Imagens_NDVI')
#         print(items.features[i].assets['NDVI'].href)
        print("Imagem baixada", items.features[i].id)
# Out:
# 13
# Imagem baixada MOD13Q1.A2011113.h13v11.006.2015218101840
# Imagem baixada MOD13Q1.A2011097.h13v11.006.2015218090054
# Imagem baixada MOD13Q1.A2011081.h13v11.006.2015217154917
# Imagem baixada MOD13Q1.A2011065.h13v11.006.2015217063307
# Imagem baixada MOD13Q1.A2011049.h13v11.006.2015216132210
# Imagem baixada MOD13Q1.A2011033.h13v11.006.2015216131350
# Imagem baixada MOD13Q1.A2011017.h13v11.006.2015216145301
# Imagem baixada MOD13Q1.A2011001.h13v11.006.2015216113656
# Imagem baixada MOD13Q1.A2010353.h13v11.006.2018226093535
# Imagem baixada MOD13Q1.A2010337.h13v11.006.2015213170139
# Imagem baixada MOD13Q1.A2010321.h13v11.006.2015213084059
# Imagem baixada MOD13Q1.A2010305.h13v11.006.2015213071832
# Imagem baixada MOD13Q1.A2010289.h13v11.006.2015211225655
# 13
# Imagem baixada MOD13Q1.A2014113.h13v11.006.2015281101017
# Imagem baixada MOD13Q1.A2014097.h13v11.006.2015278233633
# Imagem baixada MOD13Q1.A2014081.h13v11.006.2015276220454
# Imagem baixada MOD13Q1.A2014065.h13v11.006.2015276172232
# Imagem baixada MOD13Q1.A2014049.h13v11.006.2015274230335
# Imagem baixada MOD13Q1.A2014033.h13v11.006.2015274230754
# Imagem baixada MOD13Q1.A2014017.h13v11.006.2015273225920
# Imagem baixada MOD13Q1.A2014001.h13v11.006.2015272061603
# Imagem baixada MOD13Q1.A2013353.h13v11.006.2018226105929
# Imagem baixada MOD13Q1.A2013337.h13v11.006.2015271131508
# Imagem baixada MOD13Q1.A2013321.h13v11.006.2015271100034
# Imagem baixada MOD13Q1.A2013305.h13v11.006.2015270191657
# Imagem baixada MOD13Q1.A2013289.h13v11.006.2015269225046
# 13
# Imagem baixada MOD13Q1.A2016113.h13v11.006.2016130115258
# Imagem baixada MOD13Q1.A2016097.h13v11.006.2016114035551
# Imagem baixada MOD13Q1.A2016081.h13v11.006.2016111112927
# Imagem baixada MOD13Q1.A2016065.h13v11.006.2016111112513
# Imagem baixada MOD13Q1.A2016049.h13v11.006.2016109133344
# Imagem baixada MOD13Q1.A2016033.h13v11.006.2016050021641
# Imagem baixada MOD13Q1.A2016017.h13v11.006.2016035114528
# Imagem baixada MOD13Q1.A2016001.h13v11.006.2016029065707
# Imagem baixada MOD13Q1.A2015353.h13v11.006.2018222150604
# Imagem baixada MOD13Q1.A2015337.h13v11.006.2016004171600
# Imagem baixada MOD13Q1.A2015321.h13v11.006.2015343135031
# Imagem baixada MOD13Q1.A2015305.h13v11.006.2015335130638
# Imagem baixada MOD13Q1.A2015289.h13v11.006.2015317210654

# %% [markdown]
# Connect BD

# %%
# !pip install psycopg2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: psycopg2 in /usr/lib/python3.9/site-packages (2.8.6)

# %%
import psycopg2 as ps

# %%
def connect_db():

    try:
        conn = ps.connect("dbname='trabalhobd' user='postgres' host='localhost' password='secreto'")
        conn.set_session(autocommit=True) #if you want your updates to take effect without being in a transaction and requiring a commit, for a beginner, I would set this to True
        return conn
    except:
        print ("I am unable to connect to the database")
        return None

# %%
query= "SELECT * FROM recipes"
cur = conn.cursor()
cur.execute(query)
res = cur.fetchall()
print(res)
# Out:
# [(1, 'Tacos')]
